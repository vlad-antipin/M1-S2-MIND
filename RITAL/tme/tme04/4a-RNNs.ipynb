# %% [markdown]
# ## --- Generate text with a recurrent neural network (Pytorch) ---
# ### (Mostly Read & Run)
#
# The goal is to replicate the (famous) experiment from [Karpathy's blog](http://karpathy.github.io/2015/05/21/rnn-effectiveness/)
#
# To learn to generate text, we train a recurrent neural network to do the following task:
#
# Given a "chunk" of text: `this is random text`
#
# the goal of the network is to predict each character in **`his is random text` ** sequentially given the following sequential input **`this is random tex`**:

# %% [raw]
# Input ->  Output
# --------------
# T    ->    H
# H    ->    I
# I    ->    S
# S    ->    " "
# " "  ->    I
# I    ->    S
# S    ->    " "
# [...]

# %% [markdown]
# ## Load text (dataset/input.txt)
#
# Before building training batch, we load the full text in RAM

# %%
# !wget https://thome.isir.upmc.fr/classes/RITAL/input.txt
# Out:
# --2026-03-13 17:31:00--  https://thome.isir.upmc.fr/classes/RITAL/input.txt
# Resolving thome.isir.upmc.fr (thome.isir.upmc.fr)... 134.157.18.247
# Connecting to thome.isir.upmc.fr (thome.isir.upmc.fr)|134.157.18.247|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt.1’
#
# input.txt.1         100%[===================>]   1.06M  --.-KB/s    in 0.06s
#
# 2026-03-13 17:31:04 (16.4 MB/s) - ‘input.txt.1’ saved [1115394/1115394]

# %%
#! pip install unidecode

# %%
import unidecode
import string
import random
import re
import torch
import torch.nn as nn

all_characters = string.printable
n_characters = len(all_characters)

file = unidecode.unidecode(open('./input.txt').read()) #clean text => only ascii
file_len = len(file)
print('file_len =', file_len)
# Out:
# file_len = 1115394

# %% [markdown]
# ## 2: Helper functions:
#
# We have a text and we want to feed batch of chunks to a neural network:
#
# one chunk  A,B,C,D,E
# [input] A,B,C,D -> B,C,D,E [output]
#
# Note: we will use an embedding layer instead of a one-hot encoding scheme.
#
# for this, we have 3 functions:
#
# - One to get a random str chunk of size `chunk_len` : `random_chunk`
# - One to turn a chunk into a tensor of size `(1,chunk_len)` coding for each characters : `char_tensor`
# - One to return random input and output chunks of size `(batch_size,chunk_len)` : `random_training_set`

# %%
import time, math


#Get a piece of text
def random_chunk(chunk_len):
    start_index = random.randint(0, file_len - chunk_len)
    end_index = start_index + chunk_len + 1
    return file[start_index:end_index]


# Turn string into list of longs
def char_tensor(string):
    tensor = torch.zeros(1,len(string)).long()
    for c in range(len(string)):
        tensor[0,c] = all_characters.index(string[c])
    return tensor


#Turn a piece of text in train/test
def random_training_set(chunk_len=200, batch_size=8):
    chunks = [random_chunk(chunk_len) for _ in range(batch_size)]
    inp = torch.cat([char_tensor(chunk[:-1]) for chunk in chunks],dim=0)
    target = torch.cat([char_tensor(chunk[1:]) for chunk in chunks],dim=0)

    return inp, target

print(random_training_set(10,4))  ## should return 8 chunks of 10 letters.
# Out:
# (tensor([[24, 27, 23, 94, 29, 24, 94, 16, 18, 31],
#         [18, 28, 29, 27, 30, 28, 29, 14, 13, 77],
#         [94, 17, 14, 27, 14, 75, 94, 55, 10, 20],
#         [18, 22, 14, 94, 34, 24, 30, 27, 94, 22]]), tensor([[27, 23, 94, 29, 24, 94, 16, 18, 31, 14],
#         [28, 29, 27, 30, 28, 29, 14, 13, 77, 94],
#         [17, 14, 27, 14, 75, 94, 55, 10, 20, 14],
#         [22, 14, 94, 34, 24, 30, 27, 94, 22, 10]]))

# %% [markdown]
# ## The actual RNN model (only thing to complete):
#
# It should be composed of three distinct modules:
#
# - an [embedding layer](https://pytorch.org/docs/stable/nn.html#embedding) (n_characters, hidden_size)
#
# ```
# nn.Embedding(len_dic,size_vec)
# ```
# - a [recurrent](https://pytorch.org/docs/stable/nn.html#recurrent-layers) layer (hidden_size, hidden_size)
# ```
# nn.RNN(in_size,out_size) or nn.GRU() or nn.LSTM() => rnn_cell parameter
# ```
# - a [prediction](https://pytorch.org/docs/stable/nn.html#linear) layer (hidden_size, output_size)
#
# ```
# nn.Linear(in_size,out_size)
# ```
# => Complete the `init` function code

# %%
import torch.nn.functional as f

class RNN(nn.Module):

    def __init__(self, n_char, hidden_size, output_size, n_layers=1,rnn_cell=nn.RNN):
        """
        Create the network
        """
        super(RNN, self).__init__()

        self.n_char = n_char
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers

        #  (batch,chunk_len) -> (batch, chunk_len, hidden_size)
        self.embed = nn.Embedding(n_char, hidden_size)

        # (batch, chunk_len, hidden_size)  -> (batch, chunk_len, hidden_size)
        self.rnn = rnn_cell(hidden_size, hidden_size, batch_first=True)

        #(batch, chunk_len, hidden_size) -> (batch, chunk_len, output_size)
        self.predict = nn.Linear(hidden_size, output_size)

    def forward(self, input):
        """
        batched forward: input is (batch > 1,chunk_len)
        """
        input = self.embed(input)
        output,_  = self.rnn(input)
        output = self.predict(f.tanh(output))
        return output

    def forward_seq(self, input,hidden=None):
        """
        not batched forward: input is  (1,chunk_len)
        """
        input = self.embed(input)
        output,hidden  = self.rnn(input.unsqueeze(0),hidden)
        output = self.predict(f.tanh(output))
        return output,hidden

# %% [markdown]
# ## Text generation function
#
# Sample text from the model

# %%
def generate(model,prime_str='A', predict_len=100, temperature=0.8):
    prime_input = char_tensor(prime_str).squeeze(0)
    hidden = None
    predicted = prime_str+""
    # Use priming string to "build up" hidden state

    for p in range(len(prime_str)-1):
        _,hidden = model.forward_seq(prime_input[p].unsqueeze(0),hidden)

    #print(hidden.size())
    for p in range(predict_len):
        output, hidden = model.forward_seq(prime_input[-1].unsqueeze(0), hidden)
                # Sample from the network as a multinomial distribution
        # output_dist = output.data.view(-1).div(temperature).exp()
        output_dist = f.softmax(output.flatten() / temperature, dim=0) # NOTE: my version
        #print(output_dist)
        top_i = torch.multinomial(output_dist, 1)[0]
        #print(top_i)
        # Add predicted character to string and use as next input
        predicted_char = all_characters[top_i]
        predicted += predicted_char
        prime_input = torch.cat([prime_input,char_tensor(predicted_char).squeeze(0)])

    return predicted

# %% [markdown]
# ## Training loop for net

# %%
def time_since(since):
    s = time.time() - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

###Parameters
n_epochs = 20000
print_every = 100
plot_every = 10
hidden_size = 100
n_layers = 5
lr = 0.005
batch_size = 16
chunk_len = 80

####

model = RNN(n_characters, hidden_size, n_characters, n_layers) #create model
model_optimizer = torch.optim.Adam(model.parameters(), lr=lr) #create Adam optimizer
criterion = nn.CrossEntropyLoss() #chose criterion

start = time.time()
all_losses = []
loss_avg = 0


def train(inp, target):
    """
    Train sequence for one chunk:
    """
    #reset gradients
    model_optimizer.zero_grad()

    # predict output
    output = model(inp)

    #compute loss
    loss =  criterion(output.view(batch_size*chunk_len,-1), target.view(-1))

    #compute gradients and backpropagate
    loss.backward()
    model_optimizer.step()

    return loss.data.item()



for epoch in range(1, n_epochs + 1):
    loss = train(*random_training_set(chunk_len,batch_size))  #train on one chunk
    loss_avg += loss

    if epoch % print_every == 0:
        print('[%s (%d %d%%) %.4f]' % (time_since(start), epoch, epoch / n_epochs * 100, loss))
        print(generate(model,'Wh', 100), '\n')



    if epoch % plot_every == 0:
        all_losses.append(loss_avg / plot_every)
        loss_avg = 0
# Out:
#  3s (100 0%) 2.1491]
# Whour thou this wife thassech cord oft of my thome
# ssues me cood my the in thour fore the seange then
#
#  5s (200 1%) 1.9387]
# Whore aive surtoman tacfsing;
# EDABET:
# The thing sooth all in you spait.
# Nos and rood hand.
#
# PINGA:
# Wha
#
#  7s (300 1%) 1.9636]
# Whee, and theyersire will not fater, what which tous the soundof,
# The sive not negher till begeeves!
# A
#
#  9s (400 2%) 1.8697]
# Whing hear mea peave to seadl;
# I and these put my your thy here
# And welis.
#
# POUGHABELLA:
# Tould
# Airs!
#
#
#
#  12s (500 2%) 1.9529]
# Why lirden:
# That leed bean care me is to the suithied him it for the oursate; the from we wing we and
#
#  14s (600 3%) 1.8104]
# Whywing:
# How thou have
# Whichith;
# Your no goth againstice time to thou lights
# benow her,
# All which I ha
#
#  16s (700 3%) 1.8200]
# When his your will I murthal wastrorcants: when stain:
# His but to are sir mother'd, a death,
# If thoush
#
#  18s (800 4%) 1.7818]
# WhyBlod, thou of by this this the day in your comn for heart.
#
# Fencidys sweeptance,
# I can the dew it,
#
#
#  21s (900 4%) 1.7972]
# Why sower to falthot pothing my Lord by me of the proved, and find;
# But of My lord,
# And as sonstant no
#
#  23s (1000 5%) 1.6656]
# What's not your offith of in asting did shall mer spier the and be rived, be not the at night siro in
#
#  25s (1100 5%) 1.7173]
# Whathines.
#
# PROSEY:
# And this corthing on time no more
# This out pred me and sich up he now heir to bean
#
#  27s (1200 6%) 1.6280]
# Where hurn, make her stay!
#
# KING RICHARD III:
# Brrides were Here the work;
# As none the commont agatire
#
#  29s (1300 6%) 1.6727]
# Whirity, he I was courtle; man our worlding a all and of my rest,
# Ocher in the meath!
#
# Secone:
# No, and
#
#  32s (1400 7%) 1.7352]
# Whe work thy king better I am the say in his made-tows at be wong the come wares our tane bellart door
#
#  34s (1500 7%) 1.7180]
# Where these like to Herady your shire to coment, good not meat say in sir! Come, ard perressicerer som
#
#  36s (1600 8%) 1.7710]
# Wheck, and with see,
# If the shall them so the consuch with thee eneet, all that to I chill.
#
# BURENCE:
#
#
#  39s (1700 8%) 1.6892]
# Wh kin in this pease in wrack'd tick.
#
# KING GxEREN
# Is and good and the will in mardence so,
# This what
#
#  41s (1800 9%) 1.7453]
# Whather and I becomp;
# And sing, and her, and the part;
# Sir.
#
# MENENIUS:
# A know pirdence. O more truichu
#
#  43s (1900 9%) 1.7703]
# Which the gure die:
# He deady lids no crambers
# I haven wrath of Lears he you, and off him,
# That, if the
#
#  45s (2000 10%) 1.7221]
# Whather of this depoes how stand were be spenceed fung the vatal his so are yet night your side, you s
#
#  47s (2100 10%) 1.6137]
# Where.
#
# LUCIO:
# He gance matself
# To look be siell, if that lie? in the ales.
#
# DUCHUCHIO:
# Then of sorros
#
#  50s (2200 11%) 1.6871]
# What's the speak
# With comane be himself; and trit the queech! hear my sigue, whos, on then:
# Comporm'd
#
#  52s (2300 11%) 1.7128]
# What men bory a dest father.
#
# Sy
# To pleave, if her speak to the dared mistore like despatness in
# vike
#
#  54s (2400 12%) 1.7135]
# Whit of that and every the saver in the
# 'Tiol it Grom of is he in my not so senchors to things is her
#
#  56s (2500 12%) 1.6104]
# Which use chared?
#
# KING RICHARD III:
# Here they come you do be;
# Auth'd my smby man gentlemen, but was b
#
#  58s (2600 13%) 1.6610]
# Where, farting would lover pate,
# And love well this say.
#
# Servance heart in
# dettle before alart, onest
#
#  1s (2700 13%) 1.5828]
# What saistach blood love my this be be do not your now this beginolds;
# Norghouses in my liar day is th
#
#  3s (2800 14%) 1.7072]
# Who, with the martter; if the what and we was that charge words:
# I'll daughting not dost that is my pa
#
#  6s (2900 14%) 1.7003]
# When to they honour on my was!
#
# SICINIUS:
# Have to him.
#
# AUFIDIUS:
# Ay, the with out says, I day not sha
#
#  9s (3000 15%) 1.6526]
# What sower, so let the now this depess, to greath youth not unclef; say'd for there comes be games ent
#
#  11s (3100 15%) 1.5863]
# What:
# If that dear to this previthom be loston dear stature time, am I with blood and now the crack'd
#
#  14s (3200 16%) 1.6748]
# Why late very.
# 'Tis you think hourbor: and against sight darch this be no be will betried that of ther
#
#  16s (3300 16%) 1.6943]
# Whern the muspose him hastariment appeak and contely!
#
# DUCHESS OF YORK:
# Recome have to darch you offer
#
#  18s (3400 17%) 1.6258]
# Whrunce theres we preporn to boy's you to so traniorn; hose this my too, go, or ten ever trumbler
# This
#
#  21s (3500 17%) 1.6834]
# What are ditcely them, geet we betchind breeds you will me to me puther the made there came no more.
#
#
#
#  23s (3600 18%) 1.5891]
# Wheld of chill more this my, down.
#
# EDWARD:
# The and retost reath, this queen:
# Who by him,
# To prey by d
#
#  25s (3700 18%) 1.6454]
# What wight,
# And is of the noble rest be leint my counter of gr I the would the moot a long would able
#
#  28s (3800 19%) 1.7238]
# Whath give I have repose us of that as you art service shame by,
# I stable my daucher in their brother:
#
#  30s (3900 19%) 1.6664]
# Whol ears it prise the child
# Flothing beared,
# They amas is some me you was keep be how for you will th
#
#  32s (4000 20%) 1.6988]
# Whem love you altops will'd the boy--low; our thee then, stisband, prisess death-dow
# And nunstinged to
#
#  35s (4100 20%) 1.7768]
# Where stay have do shall honour's toor thereforanus
# O proundref God.
#
# ROMEO:
# I worthan: one see partin
#
#  38s (4200 21%) 1.6894]
# Whites thing loves then way; if get peritture of ever you know the blood of his the sir.
#
# MENENIUS:
# Th
#
#  40s (4300 21%) 1.5792]
# Which spence to may was you will not they will come like soul were cannot she croious as of servest th
#
#  43s (4400 22%) 1.6816]
# Whiler pitielf.
#
# DUCHESBENONIO:
# It me have the partinked of that them, place that go is of York,
# And f
#
#  45s (4500 22%) 1.6581]
# Whird,
# He were; I am behed,
# Yough be and thriat, and make me:
# To fear?
#
# LUCERTERD:
# I suppused their wi
#
#  48s (4600 23%) 1.6724]
# Which no words of Lanumselfs, and the am such rome, for ourseldentensing may not not of the diers Live
#
#  50s (4700 23%) 1.5826]
# Where,
# I are beare, of her what for a world there away our upon this I did me, And her thensence.
#
# Fir
#
#  52s (4800 24%) 1.5571]
# Whilent. Your sake meateal like to thy.
#
# TYBASTERY:
# And I will think'sught,
# Therefore thou will lons:
#
#
#  55s (4900 24%) 1.6686]
# Whel sights, they born the is hence adword to the said many did how,
# What the man your evering we had
#
#  57s (5000 25%) 1.6309]
# While to and from the subortoss?
#
# GLOUCESTER:
# Did this gate
# To proved on the sentlect you how the dead
#
#  0s (5100 25%) 1.6283]
# Whaths op'ter fairing it you have wondent not in with me his from his venged thee have the crost.
# Perf
#
#  3s (5200 26%) 1.6855]
# Whering but His will histress a wife I prace, sir? have the is the death!
#
# CAMILLO:
# If to a lad shall
#
#  5s (5300 26%) 1.6538]
# Whe sporder, handion, ack'd them hours, that the chan the call lives better that strution blows boy'd
#
#  7s (5400 27%) 1.6385]
# Whir your him am to filling the come day to for expect his cannioling that forn, fearcher your you wit
#
#  10s (5500 27%) 1.6189]
# Whether, this death, you are, baser's souls not of your will.
# Now, muse stard our of day thy barmer no
#
#  12s (5600 28%) 1.6037]
# Why the kill and the presonks in Edward
# Even to spare disin crepution,
# Thou have let it soul you thee
#
#  15s (5700 28%) 1.7791]
# Wher die regless the breath what will that their, love Edward.
# Your'st thee they disstearly! I come wa
#
#  17s (5800 28%) 1.5833]
# Whard indeed;
# Peady, you ambaily; made to light he my man
# Thy one ow a laypuper!
#
# AURDIUS:
# Dedle is th
#
#  19s (5900 29%) 1.5187]
# Why, have this can withers,
# Been my supe?
# 3 KING LENVERDOND:
# In the shell this state a kerve and son a
#
#  22s (6000 30%) 1.6240]
# Whit should have the dest shall perted seasing even be Palius you to first were best beserving then br
#
#  25s (6100 30%) 1.7487]
# Wher a he or better, is that sold sive, thou to to could what hand, you death,
# To as of so her's compo
#
#  27s (6200 31%) 1.7092]
# Why hasted and into the fiend not, sobroth, an us lord, your is an my comes is in the repesting new wh
#
#  29s (6300 31%) 1.6795]
# Why my suppes, were the devil a hering fair firm'd in the friend the grace nor his look gark at the wo
#
#  31s (6400 32%) 1.7405]
# Why, now
# The with a have did come, she thing I will amen his proved of give wintute!
# Make to thou are,
#
#  33s (6500 32%) 1.6313]
# Where you ask.
# He in this console of hear with be let make the prince?
#
# GLOOPETEGO:
# To at meagne, and
#
#  36s (6600 33%) 1.5704]
# Wh, sweet shorse Bols you
# hard's and he ere you, and you, I do mist the good her heart to the keep the
#
#  38s (6700 33%) 1.6201]
# Why thine it: and her on look what leased in of your meanst grace me of you woming a can's--
#
# KING RIC
#
#  41s (6800 34%) 1.7466]
# Why lond is neven you lady dead rese with in the rest life.
# No, sill? but couse, sir.
#
# PROSPERO:
# I com
#
#  43s (6900 34%) 1.6118]
# Whice in the percise,
# I shave dear, corried of the blown and stort say in is stoon not except both dea
#
#  46s (7000 35%) 1.6583]
# Which?
#
# PAULINA:
# I may will of use untons, thy some
# Threes and this are them?
#
# ARIEL:
#
# MIRANDABELLANUS
#
#  48s (7100 35%) 1.5616]
# Whit your gangry, and child a comely me with nollainsite that is in becool;
# And now both blood
# Have gl
#
#  51s (7200 36%) 1.5965]
# Whilf of sweases; I shall say her hound less to the he had obey, leave care to farewer your sir,
# For m
#
#  54s (7300 36%) 1.6937]
# Why most the doon shall power to the faith.
#
# RICHARD:
# Man for the platient your off the can ein that,
#
#  56s (7400 37%) 1.5566]
# Whath the dray well stay well more, you for words a sayousule's many for laws for us
# This you do, with
#
#  59s (7500 37%) 1.7750]
# Wher mely soman's him more I see,
# As you pridition beat your near you the villie'd and you, a father i
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 50
#      45     return loss.data.item()
#      49 for epoch in range(1, n_epochs + 1):
# ---> 50     loss = train(*random_training_set(chunk_len,batch_size))  #train on one chunk
#      51     loss_avg += loss
#      53     if epoch % print_every == 0:
#
# Cell In[22], line 42, in train(inp, target)
#      39 loss =  criterion(output.view(batch_size*chunk_len,-1), target.view(-1))
#      41 #compute gradients and backpropagate
# ---> 42 loss.backward()
#      43 model_optimizer.step()
#      45 return loss.data.item()
#
# File ~/miniconda3/envs/rital/lib/python3.10/site-packages/torch/_tensor.py:648, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     638 if has_torch_function_unary(self):
#     639     return handle_torch_function(
#     640         Tensor.backward,
#     641         (self,),
#    (...)
#     646         inputs=inputs,
#     647     )
# --> 648 torch.autograd.backward(
#     649     self, gradient, retain_graph, create_graph, inputs=inputs
#     650 )
#
# File ~/miniconda3/envs/rital/lib/python3.10/site-packages/torch/autograd/__init__.py:353, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     348     retain_graph = create_graph
#     350 # The reason we repeat the same comment below is that
#     351 # some Python versions print out the first line of a multi-line function
#     352 # calls in the traceback and some print out the last line
# --> 353 _engine_run_backward(
#     354     tensors,
#     355     grad_tensors_,
#     356     retain_graph,
#     357     create_graph,
#     358     inputs,
#     359     allow_unreachable=True,
#     360     accumulate_grad=True,
#     361 )
#
# File ~/miniconda3/envs/rital/lib/python3.10/site-packages/torch/autograd/graph.py:824, in _engine_run_backward(t_outputs, *args, **kwargs)
#     822     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     823 try:
# --> 824     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     825         t_outputs, *args, **kwargs
#     826     )  # Calls into the C++ engine to run the backward pass
#     827 finally:
#     828     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Visualize loss

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline

plt.figure()
plt.plot(all_losses)

# %% [markdown]
# ## Try different temperatures
#
# Changing the distribution sharpness has an impact on character sampling:
#
# more or less probable things are sampled

# %%
print(generate(model,'T', 200, temperature=1))
print("----")
print(generate(model,'Th', 200, temperature=0.8))
print("----")

print(generate(model,'Th', 200, temperature=0.5))
print("----")

print(generate(model,'Th', 200, temperature=0.3))
print("----")

print(generate(model,'Th', 200, temperature=0.1))
# Out:
# THURENCE:
# A givers my mustine
# Theme of Sarstys,
# And must or father
# A thy llade did pitise do in wour his meggor'd thou friend on, I have a father brignauces impeeture skind to the moot soveren appank,
#
# ----
# Than's beitorselfu' to blood, good as nie that it do happling to have seal: are should leave manner cursed by his proudounhed thou will their dut, in the prince, the man and not and such be dark at not
# ----
# The she supperself and you we shall be the walther me the carriant by me the died the deed and love a dead and stand the dead the procues in the the fair 'tis some not and the dead endan this cannot hav
# ----
# That she shall be so the she the dead the death, he shall be the man be the dear the end the dear the call to the cannot the death, but the should the man the dead her see in the been the dead she have
# ----
# The shall be the dead the dead the dead the dead the dead the dead the dead the dead the dead the dead the dead the dead the dead the dead the prince the dead the dead the dead the dead and the dead the

# %% [markdown]
# ### Improving this code:
#
# (a) Tinker with parameters:
#
# - Is it really necessary to have 100 dims character embeddings
# - Chunk length can be gradually increased
# - Try changing RNN cell type (GRUs - LSTMs)
#
# (b) Add GPU support to go faster
