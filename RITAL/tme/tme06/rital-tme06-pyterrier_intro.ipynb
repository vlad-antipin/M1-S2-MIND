# %% [markdown]
# # Recherche d'information : librairie PyTerrier
#
# Dans cette partie, nous nous intéressons à la librairie [PyTerrier](https://pyterrier.readthedocs.io/en/latest/#) qui permet de mettre en place diverses briques d'un moteur de recherche.
# PyTerrier est basée sur [Terrier](http://terrier.org/) qui est un moteur de recherche développé en Java.
#
# Nous allons voir :
# *   l'installation et la configuration
# *   l'indexation d'une collection
# *   l'accès à l'index
# *   l'évaluation d'un moteur de recherche

# %% [markdown]
# ## Installation ete configuration
#
# Après l'installation de la librairie, il est nécessaire d'initialiser PyTerrier pour importer les fichiers jar et démarrer la machine virtuelle associée;

# %%
# !pip install python-terrier

import pyterrier as pt
if not pt.started():
  pt.init(boot_packages=["com.github.terrierteam:terrier-prf:-SNAPSHOT"])
# Out:
# /var/folders/hr/c9xk46kd0t3c2nlgs6zkg2_h0000gn/T/ipykernel_63652/3483427117.py:4: DeprecationWarning: Call to deprecated function (or staticmethod) started. (use pt.java.started() instead) -- Deprecated since version 0.11.0.
#   if not pt.started():
# Java started and loaded: pyterrier.java.colab, pyterrier.java, pyterrier.java.24, pyterrier.terrier.java [version=5.11 (build: craig.macdonald 2025-01-13 21:29), helper_version=0.0.8]
# /var/folders/hr/c9xk46kd0t3c2nlgs6zkg2_h0000gn/T/ipykernel_63652/3483427117.py:5: DeprecationWarning: Call to deprecated method pt.init(). Deprecated since version 0.11.0.
# The following code will have the same effect:
# pt.java.add_package('com.github.terrierteam', 'terrier-prf', '-SNAPSHOT')
# pt.java.init() # optional, forces java initialisation
#   pt.init(boot_packages=["com.github.terrierteam:terrier-prf:-SNAPSHOT"])

# %% [markdown]
# ## Indexation d'une collection
#
# Il est possible d'indexer plusieurs formats de collection : format TREC, fichiers en texte brut ou en PDF, ou encore des Dataframe Pandas ([pour plus de détails](https://pyterrier.readthedocs.io/en/latest/terrier-indexing.html)).
#
# Un petit exemple à titre illustratif est foourni dans le code suivant :

# %%
import pandas as pd

# configuration de l'affichage
pd.set_option('display.max_colwidth', 150)

# le jeu de données au format DataFrame
docs_df = pd.DataFrame([
        ["d1", "this is the first document of many documents"],
        ["d2", "this is another document"],
        ["d3", "the topic of this document is unknown"]
    ], columns=["docno", "text"])

# création de l'index
indexer = pt.DFIndexer("./index_3docs", overwrite=True)         # Définition du format de données (DFIndexer())
index_ref = indexer.index(docs_df["text"], docs_df["docno"])    # Indexation des champs text et docno
# !ls -lh index_3docs/                                            # Affichage de l'index sauvegardé dans "./index_3docs/"
# Out:
# /var/folders/hr/c9xk46kd0t3c2nlgs6zkg2_h0000gn/T/ipykernel_63652/197112672.py:14: DeprecationWarning: Call to deprecated class DFIndexer. (use pt.terrier.IterDictIndexer().index(dataframe.to_dict(orient='records')) instead) -- Deprecated since version 0.11.0.
#   indexer = pt.DFIndexer("./index_3docs", overwrite=True)         # Définition du format de données (DFIndexer())
# WARNING: A restricted method in java.lang.System has been called
# WARNING: java.lang.System::load has been called by com.github.luben.zstd.util.Native in an unnamed module (file:/Users/vlad/.pyterrier/terrier-assemblies-5.11-jar-with-dependencies.jar)
# WARNING: Use --enable-native-access=ALL-UNNAMED to avoid a warning for callers in this module
# WARNING: Restricted methods will be blocked in a future release unless native access is enabled
# total 80
# -rw-r--r--  1 vlad  staff     3B May  8 20:52 data.direct.bf
# -rw-r--r--  1 vlad  staff    51B May  8 20:52 data.document.fsarrayfile
# -rw-r--r--  1 vlad  staff     4B May  8 20:52 data.inverted.bf
# -rw-r--r--  1 vlad  staff   344B May  8 20:52 data.lexicon.fsomapfile
# -rw-r--r--  1 vlad  staff   249B May  8 20:52 data.lexicon.fsomaphash
# -rw-r--r--  1 vlad  staff    33B May  8 20:52 data.meta-0.fsomapfile
# -rw-r--r--  1 vlad  staff    24B May  8 20:52 data.meta.idx
# -rw-r--r--  1 vlad  staff    48B May  8 20:52 data.meta.zdata
# -rw-r--r--  1 vlad  staff   4.1K May  8 20:52 data.properties

# %% [markdown]
# De nombreux fichiers sont créés : index direct, index inverse, méta-données de l'index et de la configuration de l'indexation, etc...
#
#
# Il est également possible de modifier la configuration de l'indexation : [voir ici](https://pyterrier.readthedocs.io/en/latest/terrier-indexing.html#indexing-configuration).
#
# Pour chager un index existant en local :

# %%
index = pt.IndexFactory.of(index_ref)

# %% [markdown]
# Il est aussi possible de voir les statistiques de l'index.
# pour connaître toutes les fonctions d'interrogation, se référencer à la [javadoc](http://terrier.org/docs/current/javadoc/org/terrier/structures/Index.html).

# %%
# statistiques de la collection
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 3
# Number of terms: 4
# Number of postings: 6
# Number of fields: 0
# Number of tokens: 7
# Field names: []
# Positions:   false

# %%
# statistiques du vocabulaire.
# Nt : document frequency : nombre de documents contenant le terme
# TF : term frequency : nombre d'occurences du terme
# maxTF : nombre d'occurences maximal pour un document
for kv in index.getLexicon():
  print("%s (%s) -> %s (%s)" % (kv.getKey(), type(kv.getKey()), kv.getValue().toString(), type(kv.getValue()) ) )
# Out:
# document (<class 'str'>) -> term0 Nt=3 TF=4 maxTF=2 @{0 0 0} (<class 'jnius.reflect.org.terrier.structures.LexiconEntry'>)
# first (<class 'str'>) -> term1 Nt=1 TF=1 maxTF=1 @{0 0 7} (<class 'jnius.reflect.org.terrier.structures.LexiconEntry'>)
# topic (<class 'str'>) -> term2 Nt=1 TF=1 maxTF=1 @{0 1 1} (<class 'jnius.reflect.org.terrier.structures.LexiconEntry'>)
# unknown (<class 'str'>) -> term3 Nt=1 TF=1 maxTF=1 @{0 1 5} (<class 'jnius.reflect.org.terrier.structures.LexiconEntry'>)

# %%
# focus sur un terme particulier
index.getLexicon()["document"].toString()
# Out:
# 'term0 Nt=3 TF=4 maxTF=2 @{0 0 0}'

# %%
# récupère les statistiques de l'index inverse à partir d'un terme particulier
pointer = index.getLexicon()["document"]
for posting in index.getInvertedIndex().getPostings(pointer):
    print(posting.toString() + " doclen=%d" % posting.getDocumentLength())
# Out:
# ID(0) TF(2) doclen=3
# ID(1) TF(1) doclen=1
# ID(2) TF(1) doclen=3

# %% [markdown]
# De plus, PyTerrier met à disposition [une collection de jeux de données pré-traités](https://pyterrier.readthedocs.io/en/latest/datasets.html).
# Dans ce qui suit, nous allons nous concentrer sur le jeu de données CORD19 qui recense des articles liés à la crise sanitaire Covid-19. Il est

# %%
dataset = pt.datasets.get_dataset('irds:cord19/trec-covid')
indexer = pt.index.IterDictIndexer('./cord19-index', text_attrs=['title', 'abstract'])
indexref = indexer.index(dataset.get_corpus_iter())
index = pt.IndexFactory.of(indexref)
# Out:
# cord19/trec-covid documents:   1%|          | 2046/192509 [00:00<00:40, 4711.67it/s]
# 21:05:44.162 [ForkJoinPool-1-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (8is9x9sc) - further warnings are suppressed
# cord19/trec-covid documents: 100%|██████████| 192509/192509 [00:14<00:00, 13710.79it/s]
# 21:05:57.528 [ForkJoinPool-1-worker-1] ERROR org.terrier.structures.indexing.Indexer -- Could not finish MetaIndexBuilder:
# java.io.IOException: Key 8lqzfj2e is not unique: 37597,11755
# For MetaIndex, to suppress, set metaindex.compressed.reverse.allow.duplicates=true
# 	at org.terrier.structures.collections.FSOrderedMapFile$MultiFSOMapWriter.mergeTwo(FSOrderedMapFile.java:1374)
# 	at org.terrier.structures.collections.FSOrderedMapFile$MultiFSOMapWriter.close(FSOrderedMapFile.java:1308)
# 	at org.terrier.structures.indexing.BaseMetaIndexBuilder.close(BaseMetaIndexBuilder.java:321)
# 	at org.terrier.structures.indexing.classical.BasicIndexer.indexDocuments(BasicIndexer.java:270)
# 	at org.terrier.structures.indexing.classical.BasicIndexer.createDirectIndex(BasicIndexer.java:388)
# 	at org.terrier.structures.indexing.Indexer.index(Indexer.java:377)
# 	at org.terrier.python.ParallelIndexer$3.apply(ParallelIndexer.java:131)
# 	at org.terrier.python.ParallelIndexer$3.apply(ParallelIndexer.java:120)
# 	at java.base/java.util.stream.ReferencePipeline$3$1.accept(ReferencePipeline.java:214)
# 	at java.base/java.util.Spliterators$ArraySpliterator.forEachRemaining(Spliterators.java:1024)
# 	at java.base/java.util.stream.AbstractPipeline.copyInto(AbstractPipeline.java:570)
# 	at java.base/java.util.stream.AbstractPipeline.wrapAndCopyInto(AbstractPipeline.java:560)
# 	at java.base/java.util.stream.ReduceOps$ReduceTask.doLeaf(ReduceOps.java:960)
# 	at java.base/java.util.stream.ReduceOps$ReduceTask.doLeaf(ReduceOps.java:934)
# 	at java.base/java.util.stream.AbstractTask.compute(AbstractTask.java:327)
# 	at java.base/java.util.concurrent.CountedCompleter.exec(CountedCompleter.java:759)
# 	at java.base/java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:511)
# 	at java.base/java.util.concurrent.ForkJoinTask.invoke(ForkJoinTask.java:680)
# 	at java.base/java.util.stream.ReduceOps$ReduceOp.evaluateParallel(ReduceOps.java:927)
# 	at java.base/java.util.stream.AbstractPipeline.evaluate(AbstractPipeline.java:264)
# 	at java.base/java.util.stream.ReferencePipeline.reduce(ReferencePipeline.java:698)
# 	at org.terrier.python.ParallelIndexer$4.call(ParallelIndexer.java:140)
# 	at org.terrier.python.ParallelIndexer$4.call(ParallelIndexer.java:137)
# 	at java.base/java.util.concurrent.ForkJoinTask$AdaptedInterruptibleCallable.compute(ForkJoinTask.java:1715)
# 	at java.base/java.util.concurrent.ForkJoinTask$InterruptibleTask.exec(ForkJoinTask.java:1659)
# 	at java.base/java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:511)
# 	at java.base/java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1450)
# 	at java.base/java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:2019)
# 	at java.base/java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:187)
# 21:05:59.043 [ForkJoinPool-1-worker-1] WARN org.terrier.structures.indexing.Indexer -- Indexed 60 empty documents

# %% [markdown]
# **Exercice 1**
#
# Afficher les statistiques de l'index Cord19 et analyser statistiques du terme "tv" (pas trop fréquent pour question d'affichage).

# %%
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 192509
# Number of terms: 158515
# Number of postings: 12290426
# Number of fields: 0
# Number of tokens: 19603234
# Field names: []
# Positions:   false

# %%
lexicon = index.getLexicon()
entry = lexicon["tv"]
print(entry)

for posting in index.getInvertedIndex().getPostings(entry):
    # TODO: other stats ?
    print(posting.toString() + " doclen=%d" % posting.getDocumentLength())
# Out:
# term18986 Nt=70 TF=183 maxTF=2147483647 @{0 16007424 2}
# ID(2777) TF(3) doclen=230
# ID(10054) TF(1) doclen=273
# ID(11115) TF(3) doclen=239
# ID(11396) TF(1) doclen=187
# ID(11998) TF(1) doclen=75
# ID(15443) TF(2) doclen=73
# ID(22159) TF(1) doclen=80
# ID(24922) TF(2) doclen=60
# ID(29671) TF(2) doclen=174
# ID(32156) TF(1) doclen=272
# ID(38532) TF(8) doclen=181
# ID(42346) TF(5) doclen=250
# ID(43113) TF(10) doclen=206
# ID(43829) TF(1) doclen=214
# ID(49420) TF(2) doclen=164
# ID(50340) TF(4) doclen=205
# ID(51298) TF(4) doclen=161
# ID(51965) TF(1) doclen=73
# ID(55321) TF(2) doclen=262
# ID(56159) TF(1) doclen=240
# ID(56638) TF(4) doclen=157
# ID(60575) TF(1) doclen=144
# ID(61226) TF(4) doclen=253
# ID(61831) TF(1) doclen=201
# ID(62509) TF(1) doclen=238
# ID(64784) TF(6) doclen=166
# ID(69551) TF(5) doclen=109
# ID(70746) TF(1) doclen=240
# ID(71655) TF(1) doclen=175
# ID(71784) TF(1) doclen=197
# ID(72685) TF(1) doclen=331
# ID(77313) TF(1) doclen=202
# ID(77512) TF(1) doclen=129
# ID(81426) TF(1) doclen=157
# ID(85336) TF(9) doclen=175
# ID(86932) TF(3) doclen=175
# ID(87660) TF(11) doclen=259
# ID(92317) TF(4) doclen=375
# ID(92318) TF(4) doclen=375
# ID(93468) TF(1) doclen=221
# ID(93469) TF(1) doclen=221
# ID(93470) TF(1) doclen=221
# ID(94464) TF(1) doclen=156
# ID(100127) TF(2) doclen=114
# ID(104277) TF(1) doclen=168
# ID(107572) TF(1) doclen=157
# ID(109543) TF(1) doclen=152
# ID(112876) TF(1) doclen=66
# ID(115225) TF(1) doclen=73
# ID(117310) TF(1) doclen=135
# ID(124580) TF(1) doclen=144
# ID(124581) TF(1) doclen=144
# ID(133016) TF(4) doclen=375
# ID(137261) TF(1) doclen=99
# ID(138078) TF(7) doclen=106
# ID(146385) TF(1) doclen=214
# ID(149236) TF(1) doclen=105
# ID(149369) TF(5) doclen=76
# ID(150489) TF(1) doclen=156
# ID(151398) TF(2) doclen=164
# ID(154850) TF(1) doclen=124
# ID(159172) TF(1) doclen=67
# ID(161158) TF(1) doclen=120
# ID(163798) TF(21) doclen=350
# ID(170377) TF(2) doclen=178
# ID(181062) TF(1) doclen=144
# ID(185736) TF(1) doclen=272
# ID(188360) TF(1) doclen=168
# ID(188498) TF(1) doclen=135
# ID(188949) TF(2) doclen=156

# %% [markdown]
# Le résultat attendu débute ainsi :
#
#
# ```
# Number of documents: 192509
# Number of terms: 158515
# Number of postings: 12290426
# Number of fields: 2
# Number of tokens: 19603234
# Field names: [title, abstract]
# Positions:   false
#
# term18986 Nt=70 TF=183 maxTF=2147483647 @{0 21226724 1} TFf=3,180
# (2777,3,F[0,3]) doclen=230
# (10054,1,F[0,1]) doclen=273
# (11115,3,F[0,3]) doclen=239
# (11396,1,F[0,1]) doclen=187
# (11998,1,F[0,1]) doclen=75
# (15443,2,F[0,2]) doclen=73
# (22159,1,F[0,1]) doclen=80
# (24922,2,F[1,1]) doclen=60
# (29671,2,F[0,2]) doclen=174
# (32156,1,F[0,1]) doclen=272
# (38532,8,F[1,7]) doclen=181
# (42346,5,F[0,5]) doclen=250
# (43113,10,F[0,10]) doclen=206
# (43829,1,F[0,1]) doclen=214
# (49420,2,F[0,2]) doclen=164
# (50340,4,F[0,4]) doclen=205
# ```

# %% [markdown]
# ## Recherche de documents à partir de l'index
#
# Pour effectuer une recherche dans l'index, il faut utiliser la fonction batchRetrieve qui prend en paramètre l'index et le modèle de pondération (tf, tf-idf, etc...). La liste des modèles supportés est disponible [ici](http://terrier.org/docs/current/javadoc/org/terrier/matching/models/package-summary.html).

# %%
br = pt.BatchRetrieve(index, wmodel="Tf") # Batch because it can process a batch with multiple queries
br.search("chemical reactions")
# Out:
# /var/folders/hr/c9xk46kd0t3c2nlgs6zkg2_h0000gn/T/ipykernel_63652/2208884884.py:1: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   br = pt.BatchRetrieve(index, wmodel="Tf") # Batch because it can process a batch with multiple queries
#     qid   docid     docno  rank  score               query
# 0     1   12409  ij3ncdb6     0   21.0  chemical reactions
# 1     1   24432  094bk0t0     1   14.0  chemical reactions
# 2     1   11268  qroxmo85     2   13.0  chemical reactions
# 3     1  120041  pb00yr0r     3   13.0  chemical reactions
# 4     1  177724  44jyy79k     4   13.0  chemical reactions
# ..   ..     ...       ...   ...    ...                 ...
# 995   1   65110  1kg5rild   995    2.0  chemical reactions
# 996   1   65338  oxt0ly5b   996    2.0  chemical reactions
# 997   1   65511  vkzwn3t8   997    2.0  chemical reactions
# 998   1   65585  41fsmwzj   998    2.0  chemical reactions
# 999   1   65694  k1ocmtx3   999    2.0  chemical reactions
#
# [1000 rows x 6 columns]

# %% [markdown]
# On récupère alors un DataFrame dont les colonnes sont les suivantes :
# *   qid : identifiant de la requête. Par défaut, il s'agit de "1", puisqu'il s'agit de notre première et unique requête.
# *   docid : l'identifiant interne de Terrier pour chaque document
# *   docno : l'identifiant unique externe (chaîne de caractères) pour chaque document
# *   score : score des documents selon le modèle choisi (ici : fréquence totale des tf des termes de la requête dans chaque document)
# *   rank : rang du document dénotant l'ordre décroissant par score.
# *   query : la requête d'entrée

# %%
# autre exemple de modèle : TF-IDF
tfidf = pt.BatchRetrieve(index, wmodel="TF_IDF")
tfidf.search("chemical reactions")
# Out:
# /var/folders/hr/c9xk46kd0t3c2nlgs6zkg2_h0000gn/T/ipykernel_63652/1836429892.py:2: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   tfidf = pt.BatchRetrieve(index, wmodel="TF_IDF")
#     qid   docid     docno  rank      score               query
# 0     1   18717  iavwkdpr     0  11.379339  chemical reactions
# 1     1  121217  msdycum2     1  10.602074  chemical reactions
# 2     1  171636  v3blnh02     2  10.364436  chemical reactions
# 3     1  147193  ei4rb8fr     3  10.352866  chemical reactions
# 4     1  170863  sj8i9ss2     4   9.433666  chemical reactions
# ..   ..     ...       ...   ...        ...                 ...
# 995   1    6381  wvw7alsc   995   4.039239  chemical reactions
# 996   1   32060  7z2pfqfb   996   4.039239  chemical reactions
# 997   1   91880  8lu58q4k   997   4.039239  chemical reactions
# 998   1  135920  xvzhb7ix   998   4.039239  chemical reactions
# 999   1  149790  6ei48sjr   999   4.039239  chemical reactions
#
# [1000 rows x 6 columns]

# %% [markdown]
# On peut aussi fournir plusieurs requêtes grâce à un dataFrame. Pour interroger l'index, on applique la fonction transform() au BatchRetriever (br).
# pour plus de détails, voir [les propriétés des transformations](https://pyterrier.readthedocs.io/en/latest/transformer.html) ainsi que les [opérations possibles](https://pyterrier.readthedocs.io/en/latest/operators.html).

# %%
import pandas as pd
queries = pd.DataFrame([["q1", "document"], ["q2", "first document"]], columns=["qid", "query"])
br.transform(queries)       # ou aussi : br(queries)
# Out:
#      qid   docid     docno  rank  score           query
# 0     q1   14569  mm7gxjf1     0   13.0        document
# 1     q1  137615  duxm9u8v     1   12.0        document
# 2     q1  189505  hxp258y8     2   11.0        document
# 3     q1   18789  x3o3a45b     3   10.0        document
# 4     q1   37445  q5wglpoj     4   10.0        document
# ...   ..     ...       ...   ...    ...             ...
# 1995  q2   89264  2kscr64t   995    3.0  first document
# 1996  q2   89265  0r1kojbq   996    3.0  first document
# 1997  q2   89737  icxug96f   997    3.0  first document
# 1998  q2   89738  kkgpfpjv   998    3.0  first document
# 1999  q2   90759  06y7c478   999    3.0  first document
#
# [2000 rows x 6 columns]

# %% [markdown]
# **Exercice 2**
#
# Ordonnancer les documents pour 3 requêtes : "covid disease", "hospital" et "home".
# La fonction d'ordonnacement devra être de la forme suivante :
#
#
# ```
# 0.4 * score_Bm25 + 0.6 * score_Dirichlet
# ```

# %%
bm25 = pt.BatchRetrieve(index, wmodel="BM25")
dirichlet = pt.BatchRetrieve(index, wmodel="DirichletLM")
queries = pd.DataFrame(
    [["q1", "covid disease"], ["q2", "hospital"], ["q3", "home"]],
    columns=["qid", "query"],
)
model = 0.4 * bm25 + 0.6 * dirichlet
model
# Out:
# /var/folders/hr/c9xk46kd0t3c2nlgs6zkg2_h0000gn/T/ipykernel_63652/3242932489.py:1: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   bm25 = pt.BatchRetrieve(index, wmodel="BM25")
# /var/folders/hr/c9xk46kd0t3c2nlgs6zkg2_h0000gn/T/ipykernel_63652/3242932489.py:2: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   dirichlet = pt.BatchRetrieve(index, wmodel="DirichletLM")
#     <div id="id-70f472ab-aa36-4c50-aa34-9b1401aa4825" class="repr_html" style="display: none;">
#         <style>#id-70f472ab-aa36-4c50-aa34-9b1401aa4825 {
#   color-scheme: light dark;
#   --pts-fg: #000000;
#   --pts-bg: #FFFFFF;
#   --pts-bg-hov: #DDDDDD;
#   --pts-alert: #a35;
#   --pts-bg-hl: #cbdff4;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825-pts-rendering-issue {
#   display: none;
# }
# @media (prefers-color-scheme: dark) {
#   #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 {
#     --pts-fg: #FFFFFF;
#     --pts-bg: #000000;
#     --pts-bg-hov: #444444;
#     --pts-bg-hl: #22476e;
#   }
# }
# [data-theme="dark"] #id-70f472ab-aa36-4c50-aa34-9b1401aa4825, [theme="dark"] #id-70f472ab-aa36-4c50-aa34-9b1401aa4825, [data-jp-theme-dark="true"] #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 {
#   --pts-fg: #FFFFFF;
#   --pts-bg: #000000;
#   --pts-bg-hov: #444444;
#   --pts-bg-hl: #22476e;
# }
# [data-theme="light"] #id-70f472ab-aa36-4c50-aa34-9b1401aa4825, [theme="light"] #id-70f472ab-aa36-4c50-aa34-9b1401aa4825, [data-jp-theme-light="true"] #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 {
#   --pts-fg: #000000;
#   --pts-bg: #FFFFFF;
#   --pts-bg-hov: #DDDDDD;
#   --pts-bg-hl: #cbdff4;
# }
#
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 {
#     position: relative;
#     min-height: 32px;
#     padding: 16px;
#     --jp-ui-font-size1: 12px;
#     display: flex !important; /* Some notebooks don't render CSS from other sources, so we set an inline display: none; which this reverts */
#     justify-content: center;
#     font-size: 12px;
#     font-family: Arial, sans-serif;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825.repr_html {
#     /* when the shown in a notebook, make sure we have sufficient height to show infoboxes */
#     min-height: 96px;
# }
#
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-infobox-hint {
#     display: none;
#     position: absolute;
#     top: 1px;
#     right: 2px;
#     background: #f59f00;
#     color: #fff;
#     padding: 0 2px;
# }
#
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-infobox {
#     position: absolute;
#     max-height: 300px;
#     top: 0;
#     left: 0;
#     border: 1px solid rgb(66, 153, 225);
#     overflow-y: auto;
#     display: none;
#     background: var(--pts-bg);
#     box-shadow: 0 0 4px var(--pts-fg);
#     opacity: 0.9;
#     margin: 4px;
#     font-size: 0.8em;
#     max-width: 360px;
#     min-width: 128px;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825.repr_html .pts-infobox {
#     max-height: calc(100% - 8px);
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-infobox-item {
#     display: none;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-infobox-title {
#     background: rgb(66, 153, 225);
#     color: white;
#     padding: 2px 6px;
#     position: sticky;
#     top: 0;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-infobox-body {
#     overflow-x: auto;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 [data-pts-infobox] {
#     cursor: pointer;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-infobox-source.pts-transformer {
#     background: rgba(66, 153, 225, 0.4);
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-infobox-source.pts-df {
#     background-color: var(--pts-bg-hov);
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-infobox-outer-error {
#     border: 1px solid var(--pts-alert);
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-infobox-outer-error > .pts-infobox-title {
#     background: var(--pts-alert);
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-infobox-error {
#     margin: 4px;
#     color: var(--pts-alert);
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-infobox-error ul {
#     margin: 0;
#     padding-left: 12px;
# }
#
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-hline {
#     width: 56px;
#     border-bottom: 2px solid var(--pts-fg);
#     align-self: center;
#     position: relative;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-arr-inner {
#     margin-right: -6px;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-arr-input {
#     margin-right: -6px;
#     width: 16px;
#     margin-left: 28px;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-arr-output {
#     width: 16px;
#     margin-right: 32px;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-arr::after {
#     content: "";
#     position: absolute;
#     right: -4px;
#     top: 1px;
#     transform: translateY(-50%);
#     width: 0;
#     height: 0;
#     border-left: 6px solid var(--pts-fg);
#     border-top: 4px solid transparent;
#     border-bottom: 4px solid transparent;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-io-label {
#     margin: 0 5px 4px 5px;
# }
#
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-vline {
#     border-right: 2px solid var(--pts-fg);
#     position: relative;
#     margin-right: -2px;
#     margin-left: -2px;
# }
#
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-df {
#     display: inline-block;
#     width: 27px;
#     height: 27px;
#     font-size: 14px;
#     color: var(--pts-fg);
#     border: 3px double var(--pts-fg);
#     background-color: var(--pts-bg);
#     box-sizing: border-box;
#     border-radius: 3px;
#     text-align: center;
#     line-height: 1;
#     padding-top: 3px;
#     margin: 1px;
#     font-weight: bold;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-df.pts-df-alert {
#     border-color: var(--pts-alert);
#     color: var(--pts-alert);
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-hline > .pts-df {
#     position: absolute;
#     top: -14px;
#     left: 12px;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-arr-input > .pts-df {
#     left: -28px;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-arr-output > .pts-df {
#     left: 22px;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-df-columns {
#     margin-bottom: 0;
#     min-width: 100%;
#     border-collapse: collapse;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-df-columns td, #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-df-columns th {
#     border-top: 1px solid #bbb;
#     background: var(--pts-bg);
#     color: var(--pts-fg);
#     text-align: left;
#     padding: 2px 2px 2px 4px;
#     white-space: nowrap;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-df-columns .pts-add th, #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-df-columns .pts-add td {
#     background-color: var(--pts-bg-hl);
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-df-columns td {
#     width: 100%;
# }
#
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-pipeline {
#     display: flex;
#     align-items: center;
#     align-content: stretch;
#     overflow-x: auto;
#     min-height: 29px;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-pipeline > * {
#     flex-shrink: 0;
# }
#
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-transformer {
#     font-size: 13px;
#     display: inline-block;
#     position: relative;
#     color: var(--pts-fg);
#     background: rgba(66, 153, 225, 0.3);
#     box-sizing: border-box;
#     padding: 4px 18px;
#     clip-path: polygon(0 0, calc(100% - 16px) 0, 100% 50%, calc(100% - 16px) 100%, 0 100%, 16px 50%);
# }
#
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-transformer-title {
#     text-align: center;
#     font-weight: bold;
# }
#
# /* re-size things within an inner block */
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-inner .pts-df {
#     width: 21px;
#     height: 21px;
#     font-size: 11px;
#     padding-top: 2px;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-inner .pts-hline {
#     width: 34px;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-inner .pts-transformer {
#     font-size: 12px;
#     padding: 3px 18px;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-inner .pts-hline > .pts-df {
#     position: absolute;
#     top: -10px;
#     left: 5px;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-inner .pts-arr-input {
#     margin-left: 8px;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-inner .pts-arr-output {
#     margin-right: 4px;
# }
#
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-inner-schematic {
#     display: flex;
#     flex-direction: column;
# }
#
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-parallel-scaffold {
#     display: grid;
#     grid-template-areas:
#       "larr title rarr"
#       "larr body  rarr";
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-parallel-scaffold > .pts-hline {
#     grid-area: larr;
#     width: 16px;
# }
# #id-70f472ab-aa36-4c50-aa34-9b1401aa4825 .pts-parallel-scaffold > .pts-hline.pts-arr {
#     grid-area: rarr;
#     margin-right: -8px

# %%
model(queries)
# Out:
#      qid     docid     docno     score          query  rank
# 0     q1  108844.0  008uxxzr  1.334152  covid disease   797
# 1     q1  160424.0  01es0zv4  1.324251  covid disease   933
# 2     q1   28210.0  028avudf  1.713311  covid disease   294
# 3     q1   28210.0  028avudf  1.704281  covid disease   302
# 4     q1       NaN  02bk8vtk  0.387548            NaN  1438
# ...   ..       ...       ...       ...            ...   ...
# 4438  q3   90427.0  zwp4g5mx  3.661162           home   675
# 4439  q3  149115.0  zxgbkj7q  3.591242           home   829
# 4440  q3  166737.0  zxs7j3bb  4.421412           home   466
# 4441  q3   27008.0  zyhhd69u  5.389105           home   186
# 4442  q3   51632.0  zzgiluha  4.521465           home   431
#
# [4443 rows x 6 columns]

# %% [markdown]
# Résultat attendu :
#
#
# ```
#      qid     docid     docno     score          query  rank
# 0     q1   43498.0  9d8go2sl  2.089712  covid disease     5
# 1     q1  106017.0  a0w3n30z  2.089712  covid disease     6
# 2     q1  106018.0  smyp9fyo  2.089712  covid disease     7
# 3     q1  106019.0  vtfn9y5p  2.089712  covid disease     8
# 4     q1   41482.0  w1vsm3rq  1.873016  covid disease    84
# ...   ..       ...       ...       ...            ...   ...
# 4727  q3       NaN  3kp3ptbn  1.018824            NaN  1433
# 4728  q3       NaN  7j98rhr8  1.018824            NaN  1434
# 4729  q3       NaN  j1gi1cxu  1.018506            NaN  1435
# 4730  q3       NaN  uknmoxu3  1.018188            NaN  1436
# 4731  q3       NaN  oe2496ql  1.017870            NaN  1437
#
# [4732 rows x 6 columns]
#      qid  docid_x     docno  rank_x   score_x        query_x  docid_y  rank_y  \
# 0     q1    43498  9d8go2sl       0  3.728774  covid disease    43498      33
# 1     q1   106017  a0w3n30z       1  3.728774  covid disease   106017      34
# 2     q1   106018  smyp9fyo       2  3.728774  covid disease   106018      35
# 3     q1   106019  vtfn9y5p       3  3.728774  covid disease   106019      36
# 4     q1    41482  w1vsm3rq       4  3.666853  covid disease    41482     509
# ...   ..      ...       ...     ...       ...            ...      ...     ...
# 1312  q3    92583  of5dvq44     995  7.577804           home    92583     661
# 1313  q3    92584  hgvt49x1     996  7.577804           home    92584     662
# 1314  q3   180665  mob8dbcr     997  7.577804           home   180665     663
# 1315  q3   172568  g73syut2     998  7.577420           home   172568     432
# 1316  q3   139621  p2ro0zdj     999  7.557501           home   139621     664
#
#        score_y        query_y     score
# 0     0.997005  covid disease  2.089712
# 1     0.997005  covid disease  2.089712
# 2     0.997005  covid disease  2.089712
# 3     0.997005  covid disease  2.089712
# 4     0.677124  covid disease  1.873016
# ...        ...            ...       ...
# 1312  1.757552           home  4.085653
# 1313  1.757552           home  4.085653
# 1314  1.757552           home  4.085653
# 1315  2.159763           home  4.326826
# 1316  1.756999           home  4.077200
#
# [1317 rows x 11 columns]
# ```

# %% [markdown]
# **Excercice 3**
#
# Créez un ordonnanceur qui effectue les opérations suivantes :
# * obtient les 10 documents les mieux notés par fréquence de terme (wmodel="Tf")
# * obtenir les 10 documents les mieux notés par TF.IDF (wmodel="TF_IDF")
# * ré-ordonne uniquement les documents trouvés dans les DEUX paramètres de recherche précédents en utilisant BM25.
#
# Combien de documents sont récupérés par ce pipeline complet pour la requête "chemical"?
#
# Vérification : le document avec le docno "37771" devrait avoir un score de 12.426309 $ pour la requête "chemical".

# %%
tf = pt.BatchRetrieve(index, wmodel="Tf")
tfidf = pt.BatchRetrieve(index, wmodel="TF_IDF")
bm25 = pt.BatchRetrieve(index, wmodel="BM25")

model = (tf%10 & tfidf%10) >> bm25
model
# Out:
# /var/folders/hr/c9xk46kd0t3c2nlgs6zkg2_h0000gn/T/ipykernel_63652/570767410.py:1: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   tf = pt.BatchRetrieve(index, wmodel="Tf")
# /var/folders/hr/c9xk46kd0t3c2nlgs6zkg2_h0000gn/T/ipykernel_63652/570767410.py:2: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   tfidf = pt.BatchRetrieve(index, wmodel="TF_IDF")
# /var/folders/hr/c9xk46kd0t3c2nlgs6zkg2_h0000gn/T/ipykernel_63652/570767410.py:3: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   bm25 = pt.BatchRetrieve(index, wmodel="BM25")
# (<pyterrier._ops.SetIntersection object at 0x119621e00> >> TerrierRetr(BM25))

# %%
model.search("chemical")
# Out:
#   qid   docid     docno  rank      score     query
# 0   1   37771  jn5qi1jb     0  12.607699  chemical
# 1   1  134305  0smev8vt     1  12.426464  chemical
# 2   1   56631  sps45fj5     2  11.883608  chemical

# %% [markdown]
# Résultat attendu :
#
#
# ```
#   qid   docid     docno  rank      score     query
# 0  q1   37771  jn5qi1jb     0  12.607699  chemical
# 1  q1  134305  0smev8vt     1  12.426464  chemical
# 2  q1   56631  sps45fj5     2  11.883608  chemical
# ```

# %% [markdown]
# ## Reformulation de requêtes
#
# Il est également possible de mettre en place des pipelines de [reformulation de requêtes](https://pyterrier.readthedocs.io/en/latest/rewrite.html).

# %%
bo1 = pt.rewrite.Bo1QueryExpansion(index)
dph = pt.BatchRetrieve(index, wmodel="DPH")
pipeline = dph >> bo1 >> dph
pipeline.search("chemical reactions")
# Out:
# /var/folders/hr/c9xk46kd0t3c2nlgs6zkg2_h0000gn/T/ipykernel_63652/2687231713.py:2: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   dph = pt.BatchRetrieve(index, wmodel="DPH")
#     qid   docid     docno  rank      score             query_0  \
# 0     1  147193  ei4rb8fr     0  22.239598  chemical reactions
# 1     1  171636  v3blnh02     1  22.204758  chemical reactions
# 2     1   18717  iavwkdpr     2  11.638978  chemical reactions
# 3     1   20409  1g9kmpdi     3  10.942838  chemical reactions
# 4     1  121217  msdycum2     4  10.616867  chemical reactions
# ..   ..     ...       ...   ...        ...                 ...
# 995   1    2550  lar2m59n   995   4.090489  chemical reactions
# 996   1   29950  lpckymwx   996   4.082916  chemical reactions
# 997   1    2556  l7s3raop   997   4.081913  chemical reactions
# 998   1  135976  1397kds0   998   4.081913  chemical reactions
# 999   1   14660  lzt06njv   999   4.078797  chemical reactions
#
#                                                                                                                                                      query
# 0    applypipeline:off chemic^1.449575286 reaction^1.300223703 hazard^0.339724370 reactiv^0.307948549 bioprocess^0.301225621 combust^0.277576853 explos...
# 1    applypipeline:off chemic^1.449575286 reaction^1.300223703 hazard^0.339724370 reactiv^0.307948549 bioprocess^0.301225621 combust^0.277576853 explos...
# 2    applypipeline:off chemic^1.449575286 reaction^1.300223703 hazard^0.339724370 reactiv^0.307948549 bioprocess^0.301225621 combust^0.277576853 explos...
# 3    applypipeline:off chemic^1.449575286 reaction^1.300223703 hazard^0.339724370 reactiv^0.307948549 bioprocess^0.301225621 combust^0.277576853 explos...
# 4    applypipeline:off chemic^1.449575286 reaction^1.300223703 hazard^0.339724370 reactiv^0.307948549 bioprocess^0.301225621 combust^0.277576853 explos...
# ..                                                                                                                                                     ...
# 995  applypipeline:off chemic^1.449575286 reaction^1.300223703 hazard^0.339724370 reactiv^0.307948549 bioprocess^0.301225621 combust^0.277576853 explos...
# 996  applypipeline:off chemic^1.449575286 reaction^1.300223703 hazard^0.339724370 reactiv^0.307948549 bioprocess^0.301225621 combust^0.277576853 explos...
# 997  applypipeline:off chemic^1.449575286 reaction^1.300223703 hazard^0.339724370 reactiv^0.307948549 bioprocess^0.301225621 combust^0.277576853 explos...
# 998  applypipeline:off chemic^1.449575286 reaction^1.300223703 hazard^0.339724370 reactiv^0.307948549 bioprocess^0.301225621 combust^0.277576853 explos...
# 999  applypipeline:off chemic^1.449575286 reaction^1.300223703 hazard^0.339724370 reactiv^0.307948549 bioprocess^0.301225621 combust^0.277576853 explos...
#
# [1000 rows x 7 columns]

# %% [markdown]
# L'autre solution est de l'intégrer directement dans la fonction d'ordonnancement. Mais la requête reformulée n'est pas visible et la solution précédente fait prendre conscience de la pipeline faite par le système de RI (ranking >> reformulation >> ranking quand on utilise des modèles basés sur la relevance feedback. ou reformulation >> ranking sinon). Plus d'exemples [ici](https://pyterrier.readthedocs.io/en/latest/rewrite.html).

# %%
# modèle DPH avant reformulation de requête
pipelineQE = pt.BatchRetrieve(index, wmodel="DPH", controls={"qemodel" : "Bo1", "qe" : "off"})
pipelineQE.search("chemical reactions")
# Out:
# /var/folders/hr/c9xk46kd0t3c2nlgs6zkg2_h0000gn/T/ipykernel_63652/1740354089.py:2: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   pipelineQE = pt.BatchRetrieve(index, wmodel="DPH", controls={"qemodel" : "Bo1", "qe" : "off"})
#     qid   docid     docno  rank      score               query
# 0     1   18717  iavwkdpr     0  12.188020  chemical reactions
# 1     1  171636  v3blnh02     1  11.867153  chemical reactions
# 2     1  147193  ei4rb8fr     2  11.858933  chemical reactions
# 3     1  121217  msdycum2     3  11.136464  chemical reactions
# 4     1  170863  sj8i9ss2     4  10.046963  chemical reactions
# ..   ..     ...       ...   ...        ...                 ...
# 995   1    6298  d752zg2b   995   4.256810  chemical reactions
# 996   1  106503  f3y5m6yg   996   4.254522  chemical reactions
# 997   1  140007  8s1lw59s   997   4.254522  chemical reactions
# 998   1   79248  iazolbhs   998   4.252125  chemical reactions
# 999   1  147194  salhgyfk   999   4.252125  chemical reactions
#
# [1000 rows x 6 columns]

# %%
# modèle DPH après reformulation de requête
pipelineQE = pt.BatchRetrieve(index, wmodel="DPH", controls={"qemodel" : "Bo1", "qe" : "on"})
pipelineQE.search("chemical reactions")
# Out:
# /var/folders/hr/c9xk46kd0t3c2nlgs6zkg2_h0000gn/T/ipykernel_63652/4229893029.py:2: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   pipelineQE = pt.BatchRetrieve(index, wmodel="DPH", controls={"qemodel" : "Bo1", "qe" : "on"})
#     qid   docid     docno  rank      score               query
# 0     1  147193  ei4rb8fr     0  22.239598  chemical reactions
# 1     1  171636  v3blnh02     1  22.204758  chemical reactions
# 2     1   18717  iavwkdpr     2  11.638978  chemical reactions
# 3     1   20409  1g9kmpdi     3  10.942838  chemical reactions
# 4     1  121217  msdycum2     4  10.616867  chemical reactions
# ..   ..     ...       ...   ...        ...                 ...
# 995   1    2550  lar2m59n   995   4.090489  chemical reactions
# 996   1   29950  lpckymwx   996   4.082916  chemical reactions
# 997   1    2556  l7s3raop   997   4.081913  chemical reactions
# 998   1  135976  1397kds0   998   4.081913  chemical reactions
# 999   1   14660  lzt06njv   999   4.078797  chemical reactions
#
# [1000 rows x 6 columns]

# %% [markdown]
# ### Evaluation d'un système de recherche d'information
#
# Pour évaluer un système de RI, il est nécessaire d'avoir un jeu de données constitué de requêtes et de jugements de pertinence.

# %%
# exemple de 5 requêtes pour cord19
cord19 = dataset
cord19.get_topics(variant='title')#.head(5)
# Out:
#    qid                                          query
# 0    1                             coronavirus origin
# 1    2        coronavirus response to weather changes
# 2    3                           coronavirus immunity
# 3    4         how do people die from the coronavirus
# 4    5                      animal models of COVID-19
# 5    6                 coronavirus test rapid testing
# 6    7              serological tests for coronavirus
# 7    8                    coronavirus under reporting
# 8    9                          coronavirus in Canada
# 9   10           coronavirus social distancing impact
# 10  11                 coronavirus hospital rationing
# 11  12                         coronavirus quarantine
# 12  13                    how does coronavirus spread
# 13  14                    coronavirus super spreaders
# 14  15                       coronavirus outside body
# 15  16  how long does coronavirus survive on surfaces
# 16  17                    coronavirus clinical trials
# 17  18                      masks prevent coronavirus
# 18  19       what alcohol sanitizer kills coronavirus
# 19  20                 coronavirus and ACE inhibitors
# 20  21                          coronavirus mortality
# 21  22                      coronavirus heart impacts
# 22  23                       coronavirus hypertension
# 23  24                           coronavirus diabetes
# 24  25                         coronavirus biomarkers
# 25  26                     coronavirus early symptoms
# 26  27                       coronavirus asymptomatic
# 27  28                 coronavirus hydroxychloroquine
# 28  29                   coronavirus drug repurposing
# 29  30                         coronavirus remdesivir
# 30  31         difference between coronavirus and flu
# 31  32                           coronavirus subtypes
# 32  33                 coronavirus vaccine candidates
# 33  34                           coronavirus recovery
# 34  35                    coronavirus public datasets
# 35  36                     SARS-CoV-2 spike structure
# 36  37               SARS-CoV-2 phylogenetic analysis
# 37  38                    COVID inflammatory response
# 38  39                        COVID-19 cytokine storm
# 39  40                          coronavirus mutations
# 40  41                  COVID-19 in African-Americans
# 41  42                         Vitamin D and COVID-19
# 42  43                       violence during pandemic
# 43  44    impact of masks on coronavirus transmission
# 44  45               coronavirus mental health impact
# 45  46                      dexamethasone coronavirus
# 46  47                  COVID-19 outcomes in children
# 47  48                   school reopening coronavirus
# 48  49               post-infection COVID-19 immunity
# 49  50                       mRNA vaccine coronavirus

# %%
# exemple de jugements de pertinence pour les 5 premières requêtes
cord19.get_qrels().head(5)
# Out:
#   qid     docno  label iteration
# 0   1  005b2j4b      2       4.5
# 1   1  00fmeepz      1         4
# 2   1  010vptx3      2       0.5
# 3   1  0194oljo      1       2.5
# 4   1  021q9884      1         4

# %% [markdown]
# **Exercice 4**
#
# A partir des requêtes et des jugements de pertinence du jeu de données CORD19, Ecrire le code qui permet d'afficher les résultats de la première requête de Cord19. L'affichage fusionnera les colonnes retournées par le BatchRetriever et les colonnes des qrels (merge sur qid et docno pour rajouter label et iteration au tableau).

# %%
topics = cord19.get_topics()
qid = '1'
query = topics[topics.qid == qid].title[0]

br = pt.BatchRetrieve(index, wmodel="BM25")
ranked_result = br.search(query)
ranked_result = ranked_result.merge(cord19.get_qrels(), on=["qid", "docno"])
ranked_result
# Out:
# There are multiple query fields available: ('title', 'description', 'narrative'). To use with pyterrier, provide variant or modify dataframe to add query column.
# /var/folders/hr/c9xk46kd0t3c2nlgs6zkg2_h0000gn/T/ipykernel_63652/2051924857.py:5: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   br = pt.BatchRetrieve(index, wmodel="BM25")
#     qid   docid     docno  rank      score               query  label  \
# 0     1  122804  75773gwg     0  11.522594  coronavirus origin      2
# 1     1  122805  kn2z7lho     1  11.522594  coronavirus origin      2
# 2     1  122806  4fb291hq     2  11.522594  coronavirus origin      1
# 3     1  135326  ne5r4d4b     3  11.522594  coronavirus origin      0
# 4     1  187888  hl967ekh     4  11.522594  coronavirus origin      2
# ..   ..     ...       ...   ...        ...                 ...    ...
# 415   1   70322  41rsi8ce   975   7.276125  coronavirus origin      1
# 416   1   70683  mmy45mhm   982   7.272946  coronavirus origin      0
# 417   1  186498  w8cvq0m5   987   7.254284  coronavirus origin      0
# 418   1  188349  r16y83dm   988   7.254284  coronavirus origin      0
# 419   1  164181  ndt8f812   992   7.250529  coronavirus origin      1
#
#     iteration
# 0           5
# 1           3
# 2           3
# 3         1.5
# 4           3
# ..        ...
# 415       4.5
# 416         5
# 417         3
# 418       1.5
# 419         2
#
# [420 rows x 8 columns]

# %% [markdown]
# Résultat attendu :
#
#
# ```
#
# qid	docid	docno	rank	score	query	label	iteration
# 0	1	122804	75773gwg	0	6.948973	coronavirus origin	2.0	5
# 1	1	122805	kn2z7lho	1	6.948973	coronavirus origin	2.0	3
# 2	1	122806	4fb291hq	2	6.948973	coronavirus origin	1.0	3
# 3	1	135326	ne5r4d4b	3	6.948973	coronavirus origin	0.0	1.5
# 4	1	187888	hl967ekh	4	6.948973	coronavirus origin	2.0	3
# ...	...	...	...	...	...	...	...	...
# 995	1	115790	d8gl78lg	995	4.331748	coronavirus origin	0.0	0
# 996	1	130709	6oiaf2cc	996	4.331748	coronavirus origin	0.0	0
# 997	1	188659	vagd9i6q	997	4.331748	coronavirus origin	0.0	0
# 998	1	155287	cetdqgff	998	4.331231	coronavirus origin	0.0	0.5
# 999	1	80393	ocwzl41r	999	4.329461	coronavirus origin	0.0	0
# 1000 rows × 8 columns
# ```

# %% [markdown]
# Il existe cependant une fonction qui permet de calculer l'efficacité de ces ordonnancements au travers des métriques d'évaluation (map, précision, rappel, ndcg, ...)

# %%
pt.Experiment(
    [tfidf],
    cord19.get_topics(variant='title'),
    cord19.get_qrels(),
    eval_metrics=["map", "ndcg"])
# Out:
#                   name       map      ndcg
# 0  TerrierRetr(TF_IDF)  0.212085  0.412176

# %% [markdown]
# **Exercice 5**
#
# Réaliser une expérience comparant l'expansion de requêtes avec le modèle Bo1 et basé sur la KL-divergence; L'expérience est réalisée sur TREC CORD19 avec le modèle de référence BM25. Vous devrez construire des pipelines appropriées (plus de détails sur [l'expansion](https://pyterrier.readthedocs.io/en/latest/rewrite.html) et les [expérimentations](https://pyterrier.readthedocs.io/en/latest/experiments.html)).
#
# Quelles approches entraînent des augmentations significatives de NDCG et MAP ou autres métriques ?

# %%
bo1 = pt.rewrite.Bo1QueryExpansion(index)
kl = pt.rewrite.KLQueryExpansion(index)
bm25 = pt.BatchRetrieve(index, wmodel="BM25")

model_bo1 = bm25 >> bo1 >> bm25
model_kl = bm25 >> kl >> bm25

pt.Experiment(
    [model_bo1, model_kl],
    cord19.get_topics(variant='title'),
    cord19.get_qrels(),
    eval_metrics=["map", "ndcg", "ndcg_cut_10"])
# Out:
# /var/folders/hr/c9xk46kd0t3c2nlgs6zkg2_h0000gn/T/ipykernel_63652/2847621205.py:3: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   bm25 = pt.BatchRetrieve(index, wmodel="BM25")
#                                                                                                                                                     name  \
# 0  (TerrierRetr(BM25) >> QueryExpansion(/Users/vlad/Documents/University/Master-MIND/M1-S2-MIND/RITAL/tme/tme06/cord19-index/data.properties,3,10,<or...
# 1  (TerrierRetr(BM25) >> QueryExpansion(/Users/vlad/Documents/University/Master-MIND/M1-S2-MIND/RITAL/tme/tme06/cord19-index/data.properties,3,10,<or...
#
#         map      ndcg  ndcg_cut_10
# 0  0.216699  0.427228     0.593839
# 1  0.219894  0.430525     0.597562

# %% [markdown]
# Résultat attendu :
#
#
# ```
# 	name	map	ndcg	ndcg_cut_10
# 0	+Bo1	0.216699	0.427228	0.593839
# 1	+RM3	0.219894	0.430525	0.597562
# ```
